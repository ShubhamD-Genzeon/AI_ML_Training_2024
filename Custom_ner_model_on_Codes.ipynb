# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamD-Genzeon/AI_ML_Training_2024/blob/main/Custom_ner_model_on_Codes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

# %%
template=[
    "The patient's insurance plan covers the cost of HCPCS code {HCPCS_CODE}, a nebulizer machine, prescribed for managing chronic respiratory conditions.",
    "Our clinic offers assistance in obtaining DME code {DME_CODE}, a motorized scooter, to enhance mobility for patients with limited ambulation.",
    "Following the outpatient procedure for cataract removal CPT code {CPT_CODE}, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.",
    "The patient was diagnosed with hypertension ICD-10 code {ICD_CODE} and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.",
    "The patient's recent diagnosis of osteoarthritis ICD-10 code {ICD_CODE} necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.",
    "The clinic offers counseling services CPT code {CPT_CODE} for mental health support, tailored to the individual needs of each patient.",
    "The patient's treatment plan includes surgery for gallbladder removal CPT code {CPT_CODE}, scheduled for  to address recurrent episodes of cholecystitis.",
    "The patient received a prescription for HCPCS code {HCPCS_CODE}, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.",
    "The clinic provides education sessions CPT code{CPT_CODE} on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).",
    "The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code {ICD_CODE}) led to the recommendation of DME code {DME_CODE}, a CPAP machine, for nocturnal respiratory support.",
    "The patient's insurance plan covers the cost of DME code {DME_CODE}, a stationary oxygen concentrator, for home use.",
    "The patient underwent HCPCS code {HCPCS_CODE}, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.",
    "Our clinic provides assistance in obtaining DME code {DME_CODE}, a standard electric wheelchair, for eligible patients.",
    "The patient underwent surgery for knee replacement ICD-10 code {ICD_CODE} and was prescribed a knee immobilizer for post-operative support.",
    "The patient's insurance plan covers the cost of DME code {DME_CODE} for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.",
    "Following the surgical procedure for (CPT code: {CPT_CODE}), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.",
    "Our clinic offers counseling services (CPT code: {CPT_CODE}) for  aimed at addressing stress and anxiety related to their recent diagnosis .",
    "The patient's treatment plan includes the use of DME code {DME_CODE}, a walker, to assist with mobility during their recovery from a procedure.",
    "The prescription for HCPCS code {HCPCS_CODE} was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).",
    "Following the outpatient procedure for procedure (CPT code: {CPT_CODE}), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.",
    "The patient's recent diagnosis of Headache (ICD-10 code: {ICD_CODE}) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.",
    "Our clinic provides education sessions (CPT code: {CPT_CODE}) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.",
    "The patient underwent surgery for respiratory surgeer (CPT code: {CPT_CODE}), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.",
    "The recent exacerbation of the condition (ICD-10 code: {ICD_CODE}) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.",
]

# %%
import random

def generate_dme_code():
    # Define the range of DME codes
    dme_code_start = 100
    dme_code_end = 8002

    # Generate a random DME code within the specified range
    dme_code = "E" + str(random.randint(dme_code_start, dme_code_end)).zfill(4)

    return dme_code



# Example usage
print("Generated DME Code:", generate_dme_code())
# Out:
# Generated DME Code: E6355

# %%
def generate_cpt_code():
    # Define the range of CPT codes
    cpt_code_start = 100
    cpt_code_end = 99499

    # Generate a random CPT code within the specified range
    cpt_code = str(random.randint(cpt_code_start, cpt_code_end)).zfill(5)

    return cpt_code

# Example usage
print("Generated CPT Code:", generate_cpt_code())
# Out:
# Generated CPT Code: 74637

# %%
def generate_icd_code():
    # Define the range of letters for the first character (A-Z)
    first_char = random.choice([chr(i) for i in range(ord('A'), ord('Z')+1)])

    # Generate two random digits for the second and third characters
    second_char = random.randint(0, 9)

    third_char = random.randint(0, 9)

    # Combine the characters to form the ICD code
    icd_code = f"{first_char}{second_char}{third_char}"

    return icd_code

# Example usage
print("Generated ICD Code:", generate_icd_code())
# Out:
# Generated ICD Code: X86

# %%
def generate_hcpcs_code():
    # Generate a random uppercase alphabetical letter for the first character
    first_char = random.choice('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

    # Generate four random digits for the numeric portion of the code
    numeric_part = ''.join(random.choices('0123456789', k=4))

    # Combine the characters to form the HCPCS code
    hcpcs_code = f"{first_char}{numeric_part}"

    return hcpcs_code

# Example usage
print("Generated HCPCS Code:", generate_hcpcs_code())
# Out:
# Generated HCPCS Code: W6738

# %%
place_holder_generator={
    "DME_CODE":generate_dme_code,
    "CPT_CODE":generate_cpt_code,
    "ICD_CODE":generate_icd_code,
    "HCPCS_CODE":generate_hcpcs_code
}
print("placeholder",place_holder_generator)
# Out:
# placeholder {'DME_CODE': <function generate_dme_code at 0x79aa158a04c0>, 'CPT_CODE': <function generate_cpt_code at 0x79aa14b91000>, 'ICD_CODE': <function generate_icd_code at 0x79aa14b90b80>, 'HCPCS_CODE': <function generate_hcpcs_code at 0x79aa14b90430>}

# %%
import re
def replace_placeholders(template, placeholder_to_generator):
    updated_text = template
    entities = []

    # Iterate over each placeholder in the template text
    while "{" in updated_text:
        # Find the next placeholder in the updated text
        match = re.search(r"\{([^{}]*)\}", updated_text)
        print("match",match)
        if not match:
            break
        placeholder = match.group(1)
        print("placeholder",placeholder)

        # Replace the placeholder with the generated value
        fake_value = placeholder_to_generator[placeholder]()
        print("fake_value",fake_value)
        start, end = match.span()
        print("start",start)
        print("end",end)
        updated_text = updated_text[:start] + fake_value + updated_text[end:]
        print("updated_text",updated_text)

        # # Update the start and end positions for entities
        # print("Placeholder:", placeholder)
        # print("Start:", start)
        # print("End:", start + len(fake_value))
        entities.append((start, start + len(fake_value), placeholder))

    return updated_text, {"entities": entities}

# %%
def generate_training_data(placeholder_to_generator, templates, num_samples):
    training_data = []

    for _ in range(num_samples):
        template = random.choice(templates)
        updated_text, entities = replace_placeholders(
            template, placeholder_to_generator
        )
        training_data.append((updated_text, entities))

    return training_data


generate_training_data(place_holder_generator,template,5000)
# Out:
# Streaming output truncated to the last 5000 lines.
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 16584, the patient was provided with HCPCS code J1729, a protective eye shield, for post-operative care.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5947
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E5947, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P8307
# start 32
# end 44
# updated_text The prescription for HCPCS code P8307 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value L27
# start 149
# end 159
# updated_text The prescription for HCPCS code P8307 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (L27).
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 82277
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 82277, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U62
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: U62) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7308
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: U62) requires the use of DME code E7308, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Q3065
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code Q3065, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0424
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E0424, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2676
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E2676, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value J33
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code J33 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4388
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code J33 necessitated the use of DME code E4388, a knee brace, to provide stability and support.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0351
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E0351, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value N09
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code N09 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7619
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E7619, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Z41
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code Z41 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value P10
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: P10) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2649
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: P10) requires the use of DME code E2649, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7026
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E7026, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1524
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E1524, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P7901
# start 32
# end 44
# updated_text The prescription for HCPCS code P7901 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value P59
# start 149
# end 159
# updated_text The prescription for HCPCS code P7901 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (P59).
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7107
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E7107, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value I64
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: I64) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3922
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: I64) requires the use of DME code E3922, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value F4283
# start 32
# end 44
# updated_text The prescription for HCPCS code F4283 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Y94
# start 149
# end 159
# updated_text The prescription for HCPCS code F4283 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (Y94).
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z6127
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code Z6127, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value P81
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code P81 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5396
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E5396 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value J58
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code J58 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value C9516
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code J58 and prescribed medication (HCPCS code: C9516) to manage blood pressure levels effectively.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 17945
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 17945), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value O6754
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 17945), the patient was provided with HCPCS code O6754, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 44440
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 44440) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 88394
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 88394 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 77143
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 77143), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S0585
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 77143), the patient was provided with HCPCS code S0585, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value G54
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code G54 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3703
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code G54 necessitated the use of DME code E3703, a knee brace, to provide stability and support.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value L36
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code L36 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E2074
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code L36 and prescribed medication (HCPCS code: E2074) to manage blood pressure levels effectively.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value V6802
# start 32
# end 44
# updated_text The prescription for HCPCS code V6802 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value T10
# start 149
# end 159
# updated_text The prescription for HCPCS code V6802 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (T10).
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6435
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E6435, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 70234
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 70234), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M3539
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 70234), and HCPCS code M3539 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0116
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E0116, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value L46
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code L46 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Q2400
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code L46 and prescribed medication (HCPCS code: Q2400) to manage blood pressure levels effectively.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value V52
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: V52) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4768
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: V52) requires the use of DME code E4768, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 58339
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 58339), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value R8673
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 58339), the patient was provided with HCPCS code R8673, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6753
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E6753, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 24726
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 24726, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z6222
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 24726, the patient was provided with HCPCS code Z6222, a protective eye shield, for post-operative care.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value B49
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code B49 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2265
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code B49 necessitated the use of DME code E2265, a knee brace, to provide stability and support.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value D48
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code D48 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 34439
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 34439 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value B0145
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code B0145, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1051
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E1051, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 48125
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 48125) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 70560
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 70560, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value I5300
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code I5300, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U54
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: U54) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2399
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: U54) requires the use of DME code E2399, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(71, 81), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Y66
# start 71
# end 81
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code Y66) led to the recommendation of DME code {DME_CODE}, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(114, 124), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6835
# start 114
# end 124
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code Y66) led to the recommendation of DME code E6835, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1358
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E1358, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S9215
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code S9215, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 86314
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 86314 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value G1395
# start 33
# end 45
# updated_text The patient underwent HCPCS code G1395, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2038
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2038, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 22957
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 22957 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 82207
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 82207, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Q72
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: Q72) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value K3135
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: Q72) necessitates the use of HCPCS code K3135, a medical brace, to provide support and stability.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value K11
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: K11) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value U0981
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: K11) necessitates the use of HCPCS code U0981, a medical brace, to provide support and stability.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 00226
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 00226), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1119
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 00226), the patient was instructed to use DME code E1119, a TENS unit, for pain management.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M8010
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code M8010, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6901
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E6901, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 35334
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 35334), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0437
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 35334), the patient was instructed to use DME code E0437, a TENS unit, for pain management.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 55484
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 55484), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value J6316
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 55484), the patient was provided with HCPCS code J6316, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 61338
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 61338), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Y0792
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 61338), the patient was provided with HCPCS code Y0792, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 29459
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 29459), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value I2090
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 29459), and HCPCS code I2090 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 11906
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code11906 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 97738
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 97738 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7517
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E7517, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 10274
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 10274) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7096
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E7096, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6142
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E6142, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value X0944
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code X0944, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value C8625
# start 33
# end 45
# updated_text The patient underwent HCPCS code C8625, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 88046
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 88046), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2146
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 88046), the patient was instructed to use DME code E2146, a TENS unit, for pain management.
# match <re.Match object; span=(71, 81), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value L52
# start 71
# end 81
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code L52) led to the recommendation of DME code {DME_CODE}, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(114, 124), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1379
# start 114
# end 124
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code L52) led to the recommendation of DME code E1379, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6046
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E6046, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 75704
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 75704, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S5008
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 75704, the patient was provided with HCPCS code S5008, a protective eye shield, for post-operative care.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P3922
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code P3922, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 92107
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code92107 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 82956
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 82956), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value D0142
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 82956), and HCPCS code D0142 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 38705
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 38705, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(71, 81), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value G92
# start 71
# end 81
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code G92) led to the recommendation of DME code {DME_CODE}, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(114, 124), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3215
# start 114
# end 124
# updated_text The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code G92) led to the recommendation of DME code E3215, a CPAP machine, for nocturnal respiratory support.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 22062
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code22062 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U63
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: U63) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6346
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: U63) requires the use of DME code E6346, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 25326
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 25326), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E2303
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 25326), the patient was provided with HCPCS code E2303, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 15619
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 15619 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 78233
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 78233), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W4115
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 78233), and HCPCS code W4115 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 06290
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 06290, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S3064
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 06290, the patient was provided with HCPCS code S3064, a protective eye shield, for post-operative care.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 94705
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 94705) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P7235
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code P7235, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Q12
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code Q12 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0508
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code Q12 necessitated the use of DME code E0508, a knee brace, to provide stability and support.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5280
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E5280, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value E58
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code E58 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value I12
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: I12) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value G5077
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: I12) necessitates the use of HCPCS code G5077, a medical brace, to provide support and stability.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5461
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E5461, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 73352
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 73352), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Q5271
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 73352), and HCPCS code Q5271 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Q9145
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code Q9145, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Y3819
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code Y3819, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 14186
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 14186), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value F1027
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 14186), and HCPCS code F1027 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value D8567
# start 32
# end 44
# updated_text The prescription for HCPCS code D8567 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value S57
# start 149
# end 159
# updated_text The prescription for HCPCS code D8567 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (S57).
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W2030
# start 32
# end 44
# updated_text The prescription for HCPCS code W2030 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value A82
# start 149
# end 159
# updated_text The prescription for HCPCS code W2030 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (A82).
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 36749
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code36749 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 79121
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 79121, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value K13
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code K13 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value N7166
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code K13 and prescribed medication (HCPCS code: N7166) to manage blood pressure levels effectively.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value G54
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: G54) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z9324
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: G54) necessitates the use of HCPCS code Z9324, a medical brace, to provide support and stability.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 58105
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 58105) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4692
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E4692, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 31357
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 31357 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 15504
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code15504 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value A60
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code A60 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6131
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code A60 necessitated the use of DME code E6131, a knee brace, to provide stability and support.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value B3458
# start 33
# end 45
# updated_text The patient underwent HCPCS code B3458, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value D7481
# start 33
# end 45
# updated_text The patient underwent HCPCS code D7481, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 58515
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code58515 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 27936
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 27936), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2645
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 27936), the patient was instructed to use DME code E2645, a TENS unit, for pain management.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2048
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2048, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W3365
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code W3365, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W4632
# start 33
# end 45
# updated_text The patient underwent HCPCS code W4632, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value O03
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code O03 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value N1502
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code O03 and prescribed medication (HCPCS code: N1502) to manage blood pressure levels effectively.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3987
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E3987, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 26550
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code26550 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value L5684
# start 33
# end 45
# updated_text The patient underwent HCPCS code L5684, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Y88
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code Y88 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value F7074
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code Y88 and prescribed medication (HCPCS code: F7074) to manage blood pressure levels effectively.
# ...
#   {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}),
#  ("The patient's recent diagnosis of osteoarthritis ICD-10 code G26 necessitated the use of DME code E3636, a knee brace, to provide stability and support.",
#   {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E6954, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ('The patient received a prescription for HCPCS code P4128, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.',
#   {'entities': [(51, 56, 'HCPCS_CODE')]}),
#  ('Following the outpatient procedure for procedure (CPT code: 43313), the patient was instructed to use DME code E4209, a TENS unit, for pain management.',
#   {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E6462, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ('Our clinic provides education sessions (CPT code: 10653) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.',
#   {'entities': [(50, 55, 'CPT_CODE')]}),
#  ('The recent exacerbation of the condition (ICD-10 code: W90) requires the use of DME code E4973, a portable oxygen concentrator, for improved respiratory function.',
#   {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E4587, a stationary oxygen concentrator, for home use.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E1558 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ("The patient's treatment plan includes the use of DME code E6111, a walker, to assist with mobility during their recovery from a procedure.",
#   {'entities': [(58, 63, 'DME_CODE')]}),
#  ('Our clinic provides education sessions (CPT code: 31567) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.',
#   {'entities': [(50, 55, 'CPT_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E3212, a stationary oxygen concentrator, for home use.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ('Following the surgical procedure for (CPT code: 44487), the patient was provided with HCPCS code T5251, a post-operative compression garment, for wound healing support.',
#   {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E7210, a stationary oxygen concentrator, for home use.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ("The patient's treatment plan includes the use of DME code E5234, a walker, to assist with mobility during their recovery from a procedure.",
#   {'entities': [(58, 63, 'DME_CODE')]}),
#  ('The recent exacerbation of the condition (ICD-10 code: E69) requires the use of DME code E2762, a portable oxygen concentrator, for improved respiratory function.',
#   {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}),
#  ("The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code Q81) led to the recommendation of DME code E3989, a CPAP machine, for nocturnal respiratory support.",
#   {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}),
#  ('Our clinic offers assistance in obtaining DME code E2585, a motorized scooter, to enhance mobility for patients with limited ambulation.',
#   {'entities': [(51, 56, 'DME_CODE')]}),
#  ('The recent exacerbation of the condition (ICD-10 code: R91) requires the use of DME code E2538, a portable oxygen concentrator, for improved respiratory function.',
#   {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E1496, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ('The clinic offers counseling services CPT code 75657 for mental health support, tailored to the individual needs of each patient.',
#   {'entities': [(47, 52, 'CPT_CODE')]}),
#  ('The patient underwent surgery for respiratory surgeer (CPT code: 42082), and HCPCS code M6473 was provided post-operatively to assist with pain management.',
#   {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}),
#  ("The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code U73) led to the recommendation of DME code E6984, a CPAP machine, for nocturnal respiratory support.",
#   {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}),
#  ('Following the surgical procedure for (CPT code: 55230), the patient was provided with HCPCS code O5478, a post-operative compression garment, for wound healing support.',
#   {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}),
#  ("The patient's treatment plan includes surgery for gallbladder removal CPT code 48858, scheduled for  to address recurrent episodes of cholecystitis.",
#   {'entities': [(79, 84, 'CPT_CODE')]}),
#  ('Our clinic offers assistance in obtaining DME code E1963, a motorized scooter, to enhance mobility for patients with limited ambulation.',
#   {'entities': [(51, 56, 'DME_CODE')]}),
#  ('The patient underwent surgery for knee replacement ICD-10 code C26 and was prescribed a knee immobilizer for post-operative support.',
#   {'entities': [(63, 66, 'ICD_CODE')]}),
#  ('Our clinic provides education sessions (CPT code: 98244) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.',
#   {'entities': [(50, 55, 'CPT_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E3170 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ('The clinic provides education sessions CPT code99342 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).',
#   {'entities': [(47, 52, 'CPT_CODE')]}),
#  ("The patient's treatment plan includes the use of DME code E4630, a walker, to assist with mobility during their recovery from a procedure.",
#   {'entities': [(58, 63, 'DME_CODE')]}),
#  ('The clinic provides education sessions CPT code39756 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).',
#   {'entities': [(47, 52, 'CPT_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code K78 and prescribed medication (HCPCS code: R2242) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ('The patient underwent surgery for respiratory surgeer (CPT code: 11081), and HCPCS code G1984 was provided post-operatively to assist with pain management.',
#   {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}),
#  ("The patient's treatment plan includes surgery for gallbladder removal CPT code 32268, scheduled for  to address recurrent episodes of cholecystitis.",
#   {'entities': [(79, 84, 'CPT_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E7481, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ('Our clinic provides education sessions (CPT code: 45239) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.',
#   {'entities': [(50, 55, 'CPT_CODE')]}),
#  ("The patient's treatment plan includes surgery for gallbladder removal CPT code 12781, scheduled for  to address recurrent episodes of cholecystitis.",
#   {'entities': [(79, 84, 'CPT_CODE')]}),
#  ('Following the surgical procedure for (CPT code: 79018), the patient was provided with HCPCS code Q7282, a post-operative compression garment, for wound healing support.',
#   {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code H38 and prescribed medication (HCPCS code: P5929) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ("The patient's insurance plan covers the cost of HCPCS code A7855, a nebulizer machine, prescribed for managing chronic respiratory conditions.",
#   {'entities': [(59, 64, 'HCPCS_CODE')]}),
#  ("The patient's treatment plan includes the use of DME code E6793, a walker, to assist with mobility during their recovery from a procedure.",
#   {'entities': [(58, 63, 'DME_CODE')]}),
#  ("The patient's treatment plan includes surgery for gallbladder removal CPT code 57807, scheduled for  to address recurrent episodes of cholecystitis.",
#   {'entities': [(79, 84, 'CPT_CODE')]}),
#  ('The prescription for HCPCS code X3944 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (S14).',
#   {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}),
#  ("The patient's insurance plan covers the cost of HCPCS code A7229, a nebulizer machine, prescribed for managing chronic respiratory conditions.",
#   {'entities': [(59, 64, 'HCPCS_CODE')]}),
#  ('Following the outpatient procedure for cataract removal CPT code 46339, the patient was provided with HCPCS code V5537, a protective eye shield, for post-operative care.',
#   {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}),
#  ('The patient underwent surgery for knee replacement ICD-10 code U49 and was prescribed a knee immobilizer for post-operative support.',
#   {'entities': [(63, 66, 'ICD_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E4326, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E6278 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ('The patient underwent surgery for knee replacement ICD-10 code O15 and was prescribed a knee immobilizer for post-operative support.',
#   {'entities': [(63, 66, 'ICD_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code O06 and prescribed medication (HCPCS code: A5599) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ('Following the outpatient procedure for cataract removal CPT code 69599, the patient was provided with HCPCS code V9660, a protective eye shield, for post-operative care.',
#   {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}),
#  ('The recent exacerbation of the condition (ICD-10 code: P14) requires the use of DME code E0582, a portable oxygen concentrator, for improved respiratory function.',
#   {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}),
#  ('The patient underwent surgery for knee replacement ICD-10 code S59 and was prescribed a knee immobilizer for post-operative support.',
#   {'entities': [(63, 66, 'ICD_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E3767, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ("The patient's insurance plan covers the cost of HCPCS code G6890, a nebulizer machine, prescribed for managing chronic respiratory conditions.",
#   {'entities': [(59, 64, 'HCPCS_CODE')]}),
#  ("The patient's recent diagnosis of osteoarthritis ICD-10 code B01 necessitated the use of DME code E5024, a knee brace, to provide stability and support.",
#   {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}),
#  ('Our clinic offers assistance in obtaining DME code E0343, a motorized scooter, to enhance mobility for patients with limited ambulation.',
#   {'entities': [(51, 56, 'DME_CODE')]}),
#  ("The patient's insurance plan covers the cost of HCPCS code B9317, a nebulizer machine, prescribed for managing chronic respiratory conditions.",
#   {'entities': [(59, 64, 'HCPCS_CODE')]}),
#  ("The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code Q07) led to the recommendation of DME code E7078, a CPAP machine, for nocturnal respiratory support.",
#   {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}),
#  ('The patient received a prescription for HCPCS code X3193, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.',
#   {'entities': [(51, 56, 'HCPCS_CODE')]}),
#  ('The clinic offers counseling services CPT code 05791 for mental health support, tailored to the individual needs of each patient.',
#   {'entities': [(47, 52, 'CPT_CODE')]}),
#  ('Our clinic provides assistance in obtaining DME code E5093, a standard electric wheelchair, for eligible patients.',
#   {'entities': [(53, 58, 'DME_CODE')]}),
#  ('The patient underwent surgery for knee replacement ICD-10 code W99 and was prescribed a knee immobilizer for post-operative support.',
#   {'entities': [(63, 66, 'ICD_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E2021, a stationary oxygen concentrator, for home use.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ("The patient underwent HCPCS code Z6919, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.",
#   {'entities': [(33, 38, 'HCPCS_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code U00 and prescribed medication (HCPCS code: M2082) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code T70 and prescribed medication (HCPCS code: F4377) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ("The patient's insurance plan covers the cost of DME code E2192 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.",
#   {'entities': [(57, 62, 'DME_CODE')]}),
#  ("The patient underwent HCPCS code P7451, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.",
#   {'entities': [(33, 38, 'HCPCS_CODE')]}),
#  ("The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code U61) led to the recommendation of DME code E1402, a CPAP machine, for nocturnal respiratory support.",
#   {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}),
#  ('Our clinic offers assistance in obtaining DME code E2423, a motorized scooter, to enhance mobility for patients with limited ambulation.',
#   {'entities': [(51, 56, 'DME_CODE')]}),
#  ('The patient was diagnosed with hypertension ICD-10 code S92 and prescribed medication (HCPCS code: B6841) to manage blood pressure levels effectively.',
#   {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}),
#  ('The patient underwent surgery for respiratory surgeer (CPT code: 05536), and HCPCS code N7414 was provided post-operatively to assist with pain management.',
#   {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}),
#  ('Our clinic offers assistance in obtaining DME code E3849, a motorized scooter, to enhance mobility for patients with limited ambulation.',
#   {'entities': [(51, 56, 'DME_CODE')]}),
#  ("The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code S91) led to the recommendation of DME code E6457, a CPAP machine, for nocturnal respiratory support.",
#   {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}),
#  ('The clinic provides education sessions CPT code60148 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).',
#   {'entities': [(47, 52, 'CPT_CODE')]}),
#  ("The patient's treatment plan includes the use of DME code E5028, a walker, to assist with mobility during their recovery from a procedure.",
#   {'entities': [(58, 63, 'DME_CODE')]}),
#  ...]

# %%
import os
import pickle

folder_path="training_data"
if not os.path.exists(folder_path):
  os.makedirs(folder_path)

pickle_file_path=os.path.join(folder_path,"spacy_training_data.pkl")

training_data=generate_training_data(place_holder_generator,template,5000)

with open(pickle_file_path,"wb") as file:
  pickle.dump(training_data,file)
# Out:
# Streaming output truncated to the last 5000 lines.
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code I8911, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 92553
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 92553, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value I4184
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 92553, the patient was provided with HCPCS code I4184, a protective eye shield, for post-operative care.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7809
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E7809, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 23023
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code23023 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 19357
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 19357) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U62
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: U62) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value V0536
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: U62) necessitates the use of HCPCS code V0536, a medical brace, to provide support and stability.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value B37
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: B37) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0157
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: B37) requires the use of DME code E0157, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value B04
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code B04 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 14879
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 14879) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value C7443
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code C7443, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 57527
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 57527) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value T2099
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code T2099, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value X15
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: X15) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0731
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: X15) requires the use of DME code E0731, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1139
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E1139 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 68814
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 68814, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value J52
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: J52) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6864
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: J52) requires the use of DME code E6864, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value F2744
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code F2744, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 48096
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 48096, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1275
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E1275, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 14286
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 14286) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z3489
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code Z3489, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z6959
# start 32
# end 44
# updated_text The prescription for HCPCS code Z6959 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value S07
# start 149
# end 159
# updated_text The prescription for HCPCS code Z6959 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (S07).
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 95560
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code95560 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value H2846
# start 33
# end 45
# updated_text The patient underwent HCPCS code H2846, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 85897
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 85897), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7063
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 85897), the patient was instructed to use DME code E7063, a TENS unit, for pain management.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3926
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E3926, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value V6176
# start 32
# end 44
# updated_text The prescription for HCPCS code V6176 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U39
# start 149
# end 159
# updated_text The prescription for HCPCS code V6176 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (U39).
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 99002
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 99002 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value U2284
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code U2284, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 40481
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 40481), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2172
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 40481), the patient was instructed to use DME code E2172, a TENS unit, for pain management.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2808
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2808, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 58736
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 58736, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value W86
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code W86 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M3589
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code W86 and prescribed medication (HCPCS code: M3589) to manage blood pressure levels effectively.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 13328
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 13328) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2933
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2933, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0970
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E0970, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value N22
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: N22) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4499
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: N22) requires the use of DME code E4499, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W2108
# start 32
# end 44
# updated_text The prescription for HCPCS code W2108 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value P53
# start 149
# end 159
# updated_text The prescription for HCPCS code W2108 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (P53).
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value K9793
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code K9793, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value N19
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: N19) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value T6114
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: N19) necessitates the use of HCPCS code T6114, a medical brace, to provide support and stability.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4412
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E4412 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value M97
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: M97) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value D0127
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: M97) necessitates the use of HCPCS code D0127, a medical brace, to provide support and stability.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0826
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E0826, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 25952
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 25952 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value I73
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code I73 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value N5079
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code I73 and prescribed medication (HCPCS code: N5079) to manage blood pressure levels effectively.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value O67
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: O67) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0177
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: O67) requires the use of DME code E0177, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 77541
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 77541, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S8435
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 77541, the patient was provided with HCPCS code S8435, a protective eye shield, for post-operative care.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 58267
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 58267), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6235
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 58267), the patient was instructed to use DME code E6235, a TENS unit, for pain management.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4801
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E4801, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U39
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code U39 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5182
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code U39 necessitated the use of DME code E5182, a knee brace, to provide stability and support.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value V18
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code V18 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value H0578
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code V18 and prescribed medication (HCPCS code: H0578) to manage blood pressure levels effectively.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 29029
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 29029, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value U4565
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 29029, the patient was provided with HCPCS code U4565, a protective eye shield, for post-operative care.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value F28
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: F28) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E5679
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: F28) necessitates the use of HCPCS code E5679, a medical brace, to provide support and stability.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M2149
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code M2149, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2441
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2441, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 65324
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 65324) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 40683
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 40683, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value J6961
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 40683, the patient was provided with HCPCS code J6961, a protective eye shield, for post-operative care.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value B20
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: B20) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value T9997
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: B20) necessitates the use of HCPCS code T9997, a medical brace, to provide support and stability.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value R00
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: R00) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5402
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: R00) requires the use of DME code E5402, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2409
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E2409, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M6476
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code M6476, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value T3919
# start 32
# end 44
# updated_text The prescription for HCPCS code T3919 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value W18
# start 149
# end 159
# updated_text The prescription for HCPCS code T3919 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (W18).
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 88166
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 88166) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4821
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E4821, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value H24
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: H24) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2632
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: H24) requires the use of DME code E2632, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 52651
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 52651), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value O7611
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 52651), and HCPCS code O7611 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 60641
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 60641, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value U0057
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 60641, the patient was provided with HCPCS code U0057, a protective eye shield, for post-operative care.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 33728
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 33728), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E1639
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 33728), and HCPCS code E1639 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4627
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E4627 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value T4351
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code T4351, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 25381
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 25381), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P3449
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 25381), and HCPCS code P3449 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value S60
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: S60) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value G7673
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: S60) necessitates the use of HCPCS code G7673, a medical brace, to provide support and stability.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 48687
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 48687), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2042
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 48687), the patient was instructed to use DME code E2042, a TENS unit, for pain management.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E7842
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E7842, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 56665
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 56665), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value G7219
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 56665), and HCPCS code G7219 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 67752
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 67752) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 68056
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 68056), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value L1411
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 68056), and HCPCS code L1411 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 11811
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 11811, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value R1560
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 11811, the patient was provided with HCPCS code R1560, a protective eye shield, for post-operative care.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 20129
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 20129, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S7418
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 20129, the patient was provided with HCPCS code S7418, a protective eye shield, for post-operative care.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 34676
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 34676), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Y4756
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 34676), the patient was provided with HCPCS code Y4756, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value D44
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: D44) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5124
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: D44) requires the use of DME code E5124, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value W57
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code W57 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value H7183
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code W57 and prescribed medication (HCPCS code: H7183) to manage blood pressure levels effectively.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2589
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2589, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 61171
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 61171), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0298
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 61171), the patient was instructed to use DME code E0298, a TENS unit, for pain management.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value X38
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code X38 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value B8485
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code X38 and prescribed medication (HCPCS code: B8485) to manage blood pressure levels effectively.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E4892
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E4892, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 66292
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 66292), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2507
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 66292), the patient was instructed to use DME code E2507, a TENS unit, for pain management.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value E11
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code E11 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W7608
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code E11 and prescribed medication (HCPCS code: W7608) to manage blood pressure levels effectively.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value R2827
# start 33
# end 45
# updated_text The patient underwent HCPCS code R2827, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6175
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E6175, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value K4984
# start 33
# end 45
# updated_text The patient underwent HCPCS code K4984, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 44999
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 44999, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 79519
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 79519, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 76923
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 76923, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W1679
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code W1679, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value V93
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: V93) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E1423
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: V93) necessitates the use of HCPCS code E1423, a medical brace, to provide support and stability.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1998
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E1998, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value M4293
# start 33
# end 45
# updated_text The patient underwent HCPCS code M4293, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(60, 70), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 26009
# start 60
# end 70
# updated_text Following the outpatient procedure for procedure (CPT code: 26009), the patient was instructed to use DME code {DME_CODE}, a TENS unit, for pain management.
# match <re.Match object; span=(111, 121), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6322
# start 111
# end 121
# updated_text Following the outpatient procedure for procedure (CPT code: 26009), the patient was instructed to use DME code E6322, a TENS unit, for pain management.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Q87
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: Q87) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value X3816
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: Q87) necessitates the use of HCPCS code X3816, a medical brace, to provide support and stability.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value S32
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: S32) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3755
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: S32) requires the use of DME code E3755, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 37081
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 37081) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 39929
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 39929, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value X2538
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 39929, the patient was provided with HCPCS code X2538, a protective eye shield, for post-operative care.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1287
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E1287, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 99217
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 99217) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 28629
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 28629) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1623
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E1623, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value K3042
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code K3042, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6674
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E6674, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 07932
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 07932) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value W01
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: W01) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value S2189
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: W01) necessitates the use of HCPCS code S2189, a medical brace, to provide support and stability.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 49041
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 49041) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 86233
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 86233, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value K5464
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 86233, the patient was provided with HCPCS code K5464, a protective eye shield, for post-operative care.
# match <re.Match object; span=(49, 59), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 51021
# start 49
# end 59
# updated_text Our clinic offers counseling services (CPT code: 51021) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6807
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E6807, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 60811
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 60811), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value F4628
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 60811), and HCPCS code F4628 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 48413
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 48413, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z0968
# start 113
# end 125
# ...
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 19155
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code19155 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(33, 45), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value U9537
# start 33
# end 45
# updated_text The patient underwent HCPCS code U9537, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 94334
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 94334), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value R0765
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 94334), the patient was provided with HCPCS code R0765, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(32, 44), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value R6212
# start 32
# end 44
# updated_text The prescription for HCPCS code R6212 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis ({ICD_CODE}).
# match <re.Match object; span=(149, 159), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value U85
# start 149
# end 159
# updated_text The prescription for HCPCS code R6212 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (U85).
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value P80
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code P80 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value J4989
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code P80 and prescribed medication (HCPCS code: J4989) to manage blood pressure levels effectively.
# match <re.Match object; span=(58, 68), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1081
# start 58
# end 68
# updated_text The patient's treatment plan includes the use of DME code E1081, a walker, to assist with mobility during their recovery from a procedure.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0868
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E0868, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3359
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E3359, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0501
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E0501, a stationary oxygen concentrator, for home use.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 30394
# start 65
# end 75
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 30394), and HCPCS code {HCPCS_CODE} was provided post-operatively to assist with pain management.
# match <re.Match object; span=(88, 100), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P3400
# start 88
# end 100
# updated_text The patient underwent surgery for respiratory surgeer (CPT code: 30394), and HCPCS code P3400 was provided post-operatively to assist with pain management.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 95769
# start 47
# end 57
# updated_text The clinic provides education sessions CPT code95769 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 84816
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 84816) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E2443
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E2443 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 08609
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 08609) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(61, 71), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value M83
# start 61
# end 71
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code M83 necessitated the use of DME code {DME_CODE}, a knee brace, to provide stability and support.
# match <re.Match object; span=(98, 108), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0674
# start 98
# end 108
# updated_text The patient's recent diagnosis of osteoarthritis ICD-10 code M83 necessitated the use of DME code E0674, a knee brace, to provide stability and support.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Q35
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: Q35) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1968
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: Q35) requires the use of DME code E1968, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(57, 67), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3848
# start 57
# end 67
# updated_text The patient's insurance plan covers the cost of DME code E3848 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 64247
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 64247, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(50, 60), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 43482
# start 50
# end 60
# updated_text Our clinic provides education sessions (CPT code: 43482) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# match <re.Match object; span=(47, 57), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 41255
# start 47
# end 57
# updated_text The clinic offers counseling services CPT code 41255 for mental health support, tailored to the individual needs of each patient.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 83449
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 83449), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value B9133
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 83449), the patient was provided with HCPCS code B9133, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value A01
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: A01) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3610
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: A01) requires the use of DME code E3610, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 62002
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 62002, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(55, 65), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value H20
# start 55
# end 65
# updated_text The recent exacerbation of the condition (ICD-10 code: H20) requires the use of DME code {DME_CODE}, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(89, 99), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6270
# start 89
# end 99
# updated_text The recent exacerbation of the condition (ICD-10 code: H20) requires the use of DME code E6270, a portable oxygen concentrator, for improved respiratory function.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E6946
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E6946, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E1758
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E1758, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(79, 89), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 11576
# start 79
# end 89
# updated_text The patient's treatment plan includes surgery for gallbladder removal CPT code 11576, scheduled for  to address recurrent episodes of cholecystitis.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value N4151
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code N4151, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(63, 73), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value Z94
# start 63
# end 73
# updated_text The patient underwent surgery for knee replacement ICD-10 code Z94 and was prescribed a knee immobilizer for post-operative support.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E3676
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E3676, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 39438
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 39438, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value E6172
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 39438, the patient was provided with HCPCS code E6172, a protective eye shield, for post-operative care.
# match <re.Match object; span=(65, 75), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 59591
# start 65
# end 75
# updated_text Following the outpatient procedure for cataract removal CPT code 59591, the patient was provided with HCPCS code {HCPCS_CODE}, a protective eye shield, for post-operative care.
# match <re.Match object; span=(113, 125), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value G3547
# start 113
# end 125
# updated_text Following the outpatient procedure for cataract removal CPT code 59591, the patient was provided with HCPCS code G3547, a protective eye shield, for post-operative care.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z3259
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code Z3259, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(57, 67), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value J16
# start 57
# end 67
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: J16) necessitates the use of HCPCS code {HCPCS_CODE}, a medical brace, to provide support and stability.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value Z8821
# start 97
# end 109
# updated_text The patient's recent diagnosis of Headache (ICD-10 code: J16) necessitates the use of HCPCS code Z8821, a medical brace, to provide support and stability.
# match <re.Match object; span=(51, 63), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value V3051
# start 51
# end 63
# updated_text The patient received a prescription for HCPCS code V3051, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# match <re.Match object; span=(59, 71), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value W0524
# start 59
# end 71
# updated_text The patient's insurance plan covers the cost of HCPCS code W0524, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# match <re.Match object; span=(56, 66), match='{ICD_CODE}'>
# placeholder ICD_CODE
# fake_value R97
# start 56
# end 66
# updated_text The patient was diagnosed with hypertension ICD-10 code R97 and prescribed medication (HCPCS code: {HCPCS_CODE}) to manage blood pressure levels effectively.
# match <re.Match object; span=(99, 111), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value V8421
# start 99
# end 111
# updated_text The patient was diagnosed with hypertension ICD-10 code R97 and prescribed medication (HCPCS code: V8421) to manage blood pressure levels effectively.
# match <re.Match object; span=(53, 63), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E0525
# start 53
# end 63
# updated_text Our clinic provides assistance in obtaining DME code E0525, a standard electric wheelchair, for eligible patients.
# match <re.Match object; span=(51, 61), match='{DME_CODE}'>
# placeholder DME_CODE
# fake_value E5970
# start 51
# end 61
# updated_text Our clinic offers assistance in obtaining DME code E5970, a motorized scooter, to enhance mobility for patients with limited ambulation.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 29285
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 29285), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value I4660
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 29285), the patient was provided with HCPCS code I4660, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(48, 58), match='{CPT_CODE}'>
# placeholder CPT_CODE
# fake_value 50322
# start 48
# end 58
# updated_text Following the surgical procedure for (CPT code: 50322), the patient was provided with HCPCS code {HCPCS_CODE}, a post-operative compression garment, for wound healing support.
# match <re.Match object; span=(97, 109), match='{HCPCS_CODE}'>
# placeholder HCPCS_CODE
# fake_value P4523
# start 97
# end 109
# updated_text Following the surgical procedure for (CPT code: 50322), the patient was provided with HCPCS code P4523, a post-operative compression garment, for wound healing support.

# %%
! pip install -U spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)

# %%
! python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 731.4 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-lg==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.25.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.5)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy.tokens import DocBin
import random

nlp=spacy.load("en_core_web_lg")
with open ('./training_data/spacy_training_data.pkl','rb') as file:
  data=pickle.load(file)

# Shuffle the data
random.shuffle(data)

#split the data into 80% training and 20% testing
split_ratio=int(len(data)*0.8)

train_data=data[:split_ratio]
test_data=data[split_ratio:]

print("length of training_data",len(train_data))
print("length of test_data",len(test_data))

db = DocBin()
for sample in train_data:
    print("sample(0)",sample[0])
    print("sample(1)",sample[1])
    doc = nlp(sample[0])
    entities = []
    for start, end, label in sample[1]["entities"]:
        span = doc.char_span(start, end, label=label)
        if span is not None:
            entities.append(span)
    doc.ents = entities
    db.add(doc)
db.to_disk("./training_data/train.spacy")
print("Training data prepared")
# the DocBin will store the example documents --test
db_test = DocBin()
for sample in test_data:
    doc = nlp(sample[0])
    entities = []
    for start, end, label in sample[1]["entities"]:
        span = doc.char_span(start, end, label=label)
        if span is not None:
            entities.append(span)
    doc.ents = entities
    db_test.add(doc)
db_test.to_disk("./training_data/test.spacy")
print("Testing data prepared")

print("Preprocessing done")
# Out:
# Streaming output truncated to the last 5000 lines.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 06813), the patient was provided with HCPCS code I0664, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E7490, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 50934 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 48658) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 97553, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: H24) requires the use of DME code E2632, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E3829, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code G16 necessitated the use of DME code E5759, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E4303, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E4080, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code G5190, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code V9807, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E0327, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code Y3280, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The prescription for HCPCS code O1100 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (C92).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The clinic offers counseling services CPT code 85324 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The clinic offers counseling services CPT code 30828 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 91809, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code T31) led to the recommendation of DME code E5104, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 82376, the patient was provided with HCPCS code I1004, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code U39 necessitated the use of DME code E5182, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 81692), the patient was provided with HCPCS code D8517, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 21179) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code R51 and prescribed medication (HCPCS code: Y8152) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 66164, the patient was provided with HCPCS code F3894, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 57320) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code D37) led to the recommendation of DME code E3532, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code W32) led to the recommendation of DME code E3364, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: Q77) necessitates the use of HCPCS code I5482, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E0561, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code N0760, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: S60) necessitates the use of HCPCS code G7673, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: X75) requires the use of DME code E3956, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E4843, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code B29 necessitated the use of DME code E6042, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code E16 necessitated the use of DME code E5517, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E6617, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The clinic provides education sessions CPT code67055 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The clinic offers counseling services CPT code 97889 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The clinic offers counseling services CPT code 00804 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 32570), the patient was provided with HCPCS code X2718, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 11341) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The prescription for HCPCS code D0878 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (S08).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: F77) necessitates the use of HCPCS code M6010, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E1924, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E1769, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 44593), and HCPCS code Q6853 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 74920), and HCPCS code A8009 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The prescription for HCPCS code L8855 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (Y26).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E2441, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E2127 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 66941), the patient was provided with HCPCS code E1387, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient received a prescription for HCPCS code K9528, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 29255, the patient was provided with HCPCS code C6069, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The prescription for HCPCS code I2997 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (L69).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 46572), and HCPCS code J1191 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E5257 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code X3127, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E3135, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 67229), and HCPCS code T0068 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E7487, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code L98 and prescribed medication (HCPCS code: V3207) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The clinic offers counseling services CPT code 63859 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E1058, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 00639) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code L26 and prescribed medication (HCPCS code: X9943) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 19287), the patient was instructed to use DME code E5051, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code U8037, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code I65 necessitated the use of DME code E1643, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E5577, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E3361, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E5290, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E7962, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 48687), the patient was instructed to use DME code E2042, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E4633, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 47258), the patient was provided with HCPCS code T1648, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E0413, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code G83) led to the recommendation of DME code E3531, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code S05 and prescribed medication (HCPCS code: V8508) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 13074), and HCPCS code J0460 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code S40) led to the recommendation of DME code E2785, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code B1025, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The clinic offers counseling services CPT code 03272 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 82352), the patient was provided with HCPCS code D0826, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 93242) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 91357), the patient was instructed to use DME code E7816, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E0525, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 90116, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code K3042, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: P35) requires the use of DME code E0126, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code S9217, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E1748, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code B7518, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient underwent HCPCS code R9141, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E5350, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 46241 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code L28 and prescribed medication (HCPCS code: P5581) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 30135), the patient was instructed to use DME code E4926, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E3981, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 22800), the patient was provided with HCPCS code R1029, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The clinic offers counseling services CPT code 60121 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code L8221, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code G74 and prescribed medication (HCPCS code: N6300) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 50622), the patient was provided with HCPCS code G2617, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 28292), the patient was instructed to use DME code E7130, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: F03) requires the use of DME code E4520, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 95411, the patient was provided with HCPCS code U1016, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The clinic provides education sessions CPT code59443 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 67630), the patient was instructed to use DME code E7567, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code I04 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code V8704, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code G92 necessitated the use of DME code E4123, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E1644 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code O3288, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient received a prescription for HCPCS code U6384, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E3872, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code Q66 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: Y15) necessitates the use of HCPCS code Y6194, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 41626) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The clinic offers counseling services CPT code 10235 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 41432), the patient was instructed to use DME code E7605, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E4808, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 82627, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 31255, the patient was provided with HCPCS code V3841, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E4240, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 22083, the patient was provided with HCPCS code I9522, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code L52 and prescribed medication (HCPCS code: M0493) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code Z94 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 21211, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: X40) necessitates the use of HCPCS code J8263, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 25381), and HCPCS code P3449 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The clinic provides education sessions CPT code76081 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code Y66 necessitated the use of DME code E2989, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 30690, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The prescription for HCPCS code N2484 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (S42).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 37938), the patient was instructed to use DME code E4696, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code M42 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: N04) necessitates the use of HCPCS code I6457, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The clinic provides education sessions CPT code54833 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E6284 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: E18) necessitates the use of HCPCS code R6494, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 09450), the patient was instructed to use DME code E5756, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code L92) led to the recommendation of DME code E5036, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 22935, the patient was provided with HCPCS code V5483, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 17034) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code L30 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E7998 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 64060), the patient was instructed to use DME code E6436, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The clinic provides education sessions CPT code25021 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 73042), and HCPCS code R7301 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E1925, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code J9034, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E5666, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code E8268, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code Y49) led to the recommendation of DME code E0116, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 83464, the patient was provided with HCPCS code D4833, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient underwent HCPCS code S5333, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 41204), the patient was instructed to use DME code E5663, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code O4841, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E6037, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The clinic provides education sessions CPT code10205 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The prescription for HCPCS code J0895 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (J65).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient underwent HCPCS code U8091, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) Following the surgical procedure for (CPT code: 39747), the patient was provided with HCPCS code H7675, a post-operative compression garment, for wound healing support.
# sample(1) {'entities': [(48, 53, 'CPT_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E6963, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code V84 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The clinic provides education sessions CPT code76913 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E2746, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code L0163, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 03283, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code E87 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The clinic offers counseling services CPT code 32334 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code B18 and prescribed medication (HCPCS code: O9460) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code W26 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 49353, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient underwent HCPCS code J4885, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient received a prescription for HCPCS code Q5163, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 31189), and HCPCS code R7019 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code Q22 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: K67) requires the use of DME code E7259, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 47152 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient underwent HCPCS code U7682, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 64273), and HCPCS code V1412 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code H61) led to the recommendation of DME code E4782, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: B01) necessitates the use of HCPCS code S5876, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code P17) led to the recommendation of DME code E6972, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The prescription for HCPCS code S1569 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (X55).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 59654), and HCPCS code H3682 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E1880, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E7087, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The prescription for HCPCS code D6186 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (U64).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 14917), the patient was instructed to use DME code E1492, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 05068) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 44909, the patient was provided with HCPCS code C2273, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 03740), the patient was instructed to use DME code E3205, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: U62) necessitates the use of HCPCS code V0536, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The prescription for HCPCS code R6212 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (U85).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 67042, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E7501, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code X5997, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes the use of DME code E3944, a walker, to assist with mobility during their recovery from a procedure.
# sample(1) {'entities': [(58, 63, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E2895, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 33274) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code W95 necessitated the use of DME code E7736, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E4326, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 99002 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 44831) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code P13 and prescribed medication (HCPCS code: J2901) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 10235, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code J9057, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 26078) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) The patient underwent HCPCS code R4243, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 97694, the patient was provided with HCPCS code Y0586, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The clinic provides education sessions CPT code79548 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E4482, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: S76) requires the use of DME code E2169, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 33988, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E2895, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 83568), and HCPCS code Q8375 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# ...
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient received a prescription for HCPCS code V3832, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code Z0858, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 32577, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient underwent HCPCS code Y2546, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 65406, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code G43 and prescribed medication (HCPCS code: L3343) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 84288, the patient was provided with HCPCS code G0180, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code C54 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code R73 necessitated the use of DME code E3831, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 06571), and HCPCS code I4299 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: N11) necessitates the use of HCPCS code O7739, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 37689, the patient was provided with HCPCS code Y2738, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code D98) led to the recommendation of DME code E5787, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 85342, the patient was provided with HCPCS code N3244, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 74447), and HCPCS code B5728 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E3015 for SreeLekha, prescribed to aid in their rehabilitation following a motor vehicle accident.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of DME code E7910, a stationary oxygen concentrator, for home use.
# sample(1) {'entities': [(57, 62, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code N5849, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for knee replacement ICD-10 code R37 and was prescribed a knee immobilizer for post-operative support.
# sample(1) {'entities': [(63, 66, 'ICD_CODE')]}
# sample(0) The prescription for HCPCS code U1493 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (X09).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: Q35) requires the use of DME code E1968, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code S01 and prescribed medication (HCPCS code: U4792) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) The prescription for HCPCS code S2695 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (F11).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 07621) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E1921, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E5478, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code N95) led to the recommendation of DME code E7906, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E7717, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code L4506, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: C48) necessitates the use of HCPCS code E8230, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E0514, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code P7314, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 31175), and HCPCS code W4974 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 30874, the patient was provided with HCPCS code H9244, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code M24) led to the recommendation of DME code E1116, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) The patient underwent HCPCS code Z5504, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The clinic provides education sessions CPT code19860 on proper nutrition and lifestyle modifications to support patients with diabetes (ICD-10 code: E11.9).
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 71241), the patient was instructed to use DME code E6547, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 10341 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of osteoarthritis ICD-10 code O20 necessitated the use of DME code E3213, a knee brace, to provide stability and support.
# sample(1) {'entities': [(61, 64, 'ICD_CODE'), (98, 103, 'DME_CODE')]}
# sample(0) Our clinic offers counseling services (CPT code: 20548) for  aimed at addressing stress and anxiety related to their recent diagnosis .
# sample(1) {'entities': [(49, 54, 'CPT_CODE')]}
# sample(0) The patient underwent HCPCS code X4301, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code Q3699, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The clinic offers counseling services CPT code 14707 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: A89) necessitates the use of HCPCS code K5100, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient underwent HCPCS code H2934, an established patient office visit, during which the physician performed a comprehensive examination and reviewed the patient's medical history.
# sample(1) {'entities': [(33, 38, 'HCPCS_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E6458, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient's recent diagnosis of Headache (ICD-10 code: X29) necessitates the use of HCPCS code C0134, a medical brace, to provide support and stability.
# sample(1) {'entities': [(57, 60, 'ICD_CODE'), (97, 102, 'HCPCS_CODE')]}
# sample(0) The patient underwent surgery for respiratory surgeer (CPT code: 20737), and HCPCS code O5628 was provided post-operatively to assist with pain management.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (88, 93, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 88519, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: R14) requires the use of DME code E6676, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E2611, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 00925, the patient was provided with HCPCS code H3475, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code A28 and prescribed medication (HCPCS code: K4824) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for cataract removal CPT code 19038, the patient was provided with HCPCS code P0802, a protective eye shield, for post-operative care.
# sample(1) {'entities': [(65, 70, 'CPT_CODE'), (113, 118, 'HCPCS_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 28787), the patient was instructed to use DME code E2396, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's insurance plan covers the cost of HCPCS code S5344, a nebulizer machine, prescribed for managing chronic respiratory conditions.
# sample(1) {'entities': [(59, 64, 'HCPCS_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 68066, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The patient's recent diagnosis of obstructive sleep apnea (ICD-10 code D88) led to the recommendation of DME code E4771, a CPAP machine, for nocturnal respiratory support.
# sample(1) {'entities': [(71, 74, 'ICD_CODE'), (114, 119, 'DME_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E1833, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) The patient received a prescription for HCPCS code J6179, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) Our clinic provides education sessions (CPT code: 68175) on lifestyle modifications for Deva, focusing on dietary changes and physical activity to manage their the condition.
# sample(1) {'entities': [(50, 55, 'CPT_CODE')]}
# sample(0) Our clinic provides assistance in obtaining DME code E5069, a standard electric wheelchair, for eligible patients.
# sample(1) {'entities': [(53, 58, 'DME_CODE')]}
# sample(0) Following the outpatient procedure for procedure (CPT code: 91644), the patient was instructed to use DME code E0986, a TENS unit, for pain management.
# sample(1) {'entities': [(60, 65, 'CPT_CODE'), (111, 116, 'DME_CODE')]}
# sample(0) The patient's treatment plan includes surgery for gallbladder removal CPT code 80078, scheduled for  to address recurrent episodes of cholecystitis.
# sample(1) {'entities': [(79, 84, 'CPT_CODE')]}
# sample(0) The recent exacerbation of the condition (ICD-10 code: T28) requires the use of DME code E2902, a portable oxygen concentrator, for improved respiratory function.
# sample(1) {'entities': [(55, 58, 'ICD_CODE'), (89, 94, 'DME_CODE')]}
# sample(0) The clinic offers counseling services CPT code 80093 for mental health support, tailored to the individual needs of each patient.
# sample(1) {'entities': [(47, 52, 'CPT_CODE')]}
# sample(0) Our clinic offers assistance in obtaining DME code E5663, a motorized scooter, to enhance mobility for patients with limited ambulation.
# sample(1) {'entities': [(51, 56, 'DME_CODE')]}
# sample(0) The prescription for HCPCS code Q5813 was filled for jackson, who requires ongoing management of the condition as per their recent ICD-10 diagnosis (I89).
# sample(1) {'entities': [(32, 37, 'HCPCS_CODE'), (149, 152, 'ICD_CODE')]}
# sample(0) The patient received a prescription for HCPCS code W2298, a continuous glucose monitoring system, to manage diabetes mellitus (ICD-10 code: E11.9) effectively.
# sample(1) {'entities': [(51, 56, 'HCPCS_CODE')]}
# sample(0) The patient was diagnosed with hypertension ICD-10 code D61 and prescribed medication (HCPCS code: L2658) to manage blood pressure levels effectively.
# sample(1) {'entities': [(56, 59, 'ICD_CODE'), (99, 104, 'HCPCS_CODE')]}
# Training data prepared
# Testing data prepared
# Preprocessing done

# %%
# !python -m spacy init fill-config base_config.cfg config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %%
# !python -m spacy train config.cfg --output ./output --paths.train ./training_data/train.spacy --paths.dev ./training_data/test.spacy
# Out:
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     40.11    0.00    0.00    0.00    0.00
#   0     200          6.61    890.85  100.00  100.00  100.00    1.00
#   0     400          0.02      0.04  100.00  100.00  100.00    1.00
#   0     600          0.00      0.00  100.00  100.00  100.00    1.00
#   1     800          0.00      0.00  100.00  100.00  100.00    1.00
#   1    1000          0.00      0.00  100.00  100.00  100.00    1.00
#   1    1200          0.00      0.00  100.00  100.00  100.00    1.00
#   2    1400          0.00      0.00  100.00  100.00  100.00    1.00
#   3    1600          0.00      0.00  100.00  100.00  100.00    1.00
#   4    1800          3.00      1.07  100.00  100.00  100.00    1.00
# ✔ Saved pipeline to output directory
# output/model-last

# %%
# !python -m spacy evaluate ./output/model-best/ ./training_data/test.spacy
# Out:
# ℹ Using CPU
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   100.00
# NER R   100.00
# NER F   100.00
# SPEED   18547
#
#
# =============================== NER (per type) ===============================
#
#                   P        R        F
# HCPCS_CODE   100.00   100.00   100.00
# ICD_CODE     100.00   100.00   100.00
# DME_CODE     100.00   100.00   100.00
# CPT_CODE     100.00   100.00   100.00

# %%
# import os
# output_dir="/content/model-last"
# if not os.path.exists(output_dir):
#   os.makedirs(output_dir)

# nlp.to_disk(output_dir)

# print("Model saved succesfully to :", output_dir)
# Out:
# Model saved succesfully to : /content/model-last

# %%
from spacy import displacy

# %%
nlp = spacy.load("./output/model-last/")

if not nlp:
    print("Model is not loaded...")
else:
    text_list = ["The patient underwent surgery for gallbladder removal ICD code N52, scheduled for tomorrow to address recurrent episodes of cholecystitis.",
                 "The patient underwent surgery for knee replacement  M17 and was prescribed a knee immobilizer  L1832 for post-operative support.",
                 "Following the outpatient procedure for cataract removal  66984, the patient was provided with V2799, a protective eye shield, for post-operative care."]

    # Define custom colors for entity labels
    colors = {"ICD_CODE": "#7aecec", "HCPCS_CODE": "#ff9561", "CPT_CODE": "#af74eb", "DME_CODE": "#c3bef0"}

    for text in text_list:
      doc = nlp(text)
      displacy.render(doc, style="ent", jupyter=True, options={"colors": colors})
      # for ent in doc.ents:
      #     print(f"Word -> {ent.text} -------- Label -> {ent.label_}")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient underwent surgery for gallbladder removal ICD code
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     N52
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ICD_CODE</span>
# </mark>
# , scheduled for tomorrow to address recurrent episodes of cholecystitis.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The patient underwent surgery for knee replacement
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     M17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ICD_CODE</span>
# </mark>
#  and was prescribed a knee immobilizer
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     L1832
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HCPCS_CODE</span>
# </mark>
#  for post-operative support.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Following the outpatient procedure for cataract removal
# <mark class="entity" style="background: #af74eb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     66984
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CPT_CODE</span>
# </mark>
# , the patient was provided with
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     V2799
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">HCPCS_CODE</span>
# </mark>
# , a protective eye shield, for post-operative care.</div></span>
